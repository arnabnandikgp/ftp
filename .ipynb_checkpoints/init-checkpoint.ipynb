# %%
import pandas as pd

# %%
df=pd.read_csv('training_label.csv')
df
# Out:
#                 DHSID  DHSYEAR  DHSCLUST     LATNUM    LONGNUM  Mean_BMI
# 0      AL200800000001     2008       1.0  40.822652  19.838321     24.12  \
# 1      AL200800000002     2008       2.0  40.696846  20.007555     23.04
# 2      AL200800000004     2008       4.0  40.798931  19.863338     26.74
# 3      AL200800000006     2008       6.0  40.711349  19.935309     27.58
# 4      AL200800000010     2008      10.0  40.698522  19.950300     24.23
# ...               ...      ...       ...        ...        ...       ...
# 99107  ZW201500000395     2015     395.0 -17.166506  29.718371     21.92
# 99108  ZW201500000396     2015     396.0 -17.915288  31.156115     23.16
# 99109  ZW201500000397     2015     397.0 -18.379501  31.872287     24.33
# 99110  ZW201500000398     2015     398.0 -16.660612  29.850649     23.70
# 99111  ZW201500000400     2015     400.0 -17.859114  31.797626     25.84
#
#        Median_BMI  Unmet_Need_Rate  Under5_Mortality_Rate
# ...
